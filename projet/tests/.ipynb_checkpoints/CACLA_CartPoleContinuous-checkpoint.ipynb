# %% [markdown]
# # Test environnement CartPoleContinuous avec CACLA

# %% [markdown]
# Reproduction de l'environnement de test CartPoleContinuous pour le papier https://dspace.library.uu.nl/bitstream/handle/1874/25514/wiering_07_reinforcementlearning.pdf

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import torch
import sys
import numpy as np

sys.path.insert(0, '../')
from utils.CartPoleContinuous import ContinuousCartPoleEnv
from utils.Critic import CriticNetwork
from utils.Actor import ActorNetwork
from utils.CACLA import CACLA
from utils.CACLAVAR import CACLAVAR

from tqdm import tqdm

# %% [markdown]
# ## hyper paramètres

# %%
action_space = 1
observation_space = 4

env = ContinuousCartPoleEnv()
actor_network = ActorNetwork(
    nb_neurons = 12,
    action_space = env.action_space,
    observation_space = env.observation_space
)

critic_network = CriticNetwork(
    nb_neurons = 12,
    observation_space = env.observation_space
)

cacla = CACLAVAR(
    learning_rate_critic = 0.01,
    learning_rate_actor = 0.01,
    discount_factor = 0.95,
    sigma = 0.3,
    nb_episode = 2000,
    nb_tests = 5,
    test_frequency = 10,
    env = env,
    actor_network = actor_network,
    critic_network = critic_network,
    exploration_strategy = "gaussian"
)

# %% [markdown]
# ## Learning

# %%
cacla.learning()
# Out:
# 0/2000 - iteration : 7 - rewards value test : 0.7214285714285715 - best value : -10000000000.0
# 10/2000 - iteration : 127 - rewards value test : 0.8451282051282052 - best value : 0.7214285714285715
# 20/2000 - iteration : 288 - rewards value test : 0.763968253968254 - best value : 0.8451282051282052
# 30/2000 - iteration : 361 - rewards value test : 0.7214285714285715 - best value : 0.8451282051282052
# 40/2000 - iteration : 446 - rewards value test : 0.7261904761904762 - best value : 0.8451282051282052
# 50/2000 - iteration : 527 - rewards value test : 0.7977777777777778 - best value : 0.8451282051282052
# 60/2000 - iteration : 635 - rewards value test : 0.7023809523809523 - best value : 0.8451282051282052
# 70/2000 - iteration : 706 - rewards value test : 0.6 - best value : 0.8451282051282052
# 80/2000 - iteration : 764 - rewards value test : 0.6761904761904761 - best value : 0.8451282051282052
# 90/2000 - iteration : 824 - rewards value test : 0.6399999999999999 - best value : 0.8451282051282052
# 100/2000 - iteration : 876 - rewards value test : 0.6 - best value : 0.8451282051282052
# 110/2000 - iteration : 923 - rewards value test : 0.54 - best value : 0.8451282051282052
# 120/2000 - iteration : 974 - rewards value test : 0.6 - best value : 0.8451282051282052
# 130/2000 - iteration : 1027 - rewards value test : 0.6 - best value : 0.8451282051282052
# 140/2000 - iteration : 1080 - rewards value test : 0.6857142857142857 - best value : 0.8451282051282052
# 150/2000 - iteration : 1149 - rewards value test : 0.6761904761904762 - best value : 0.8451282051282052
# 160/2000 - iteration : 1226 - rewards value test : 0.8236363636363636 - best value : 0.8451282051282052
# 170/2000 - iteration : 1393 - rewards value test : 0.7955555555555556 - best value : 0.8451282051282052
# 180/2000 - iteration : 1567 - rewards value test : 0.8125252525252525 - best value : 0.8451282051282052
# 190/2000 - iteration : 1675 - rewards value test : 0.816969696969697 - best value : 0.8451282051282052
# 200/2000 - iteration : 1808 - rewards value test : 0.7711111111111111 - best value : 0.8451282051282052
# 210/2000 - iteration : 2022 - rewards value test : 0.853306342780027 - best value : 0.8451282051282052
# 220/2000 - iteration : 2143 - rewards value test : 0.7799999999999999 - best value : 0.853306342780027
# 230/2000 - iteration : 2304 - rewards value test : 0.8718124685771744 - best value : 0.853306342780027
# 240/2000 - iteration : 2455 - rewards value test : 0.8831372549019608 - best value : 0.8718124685771744
# 250/2000 - iteration : 2649 - rewards value test : 0.9420405045405046 - best value : 0.8831372549019608
# 260/2000 - iteration : 2975 - rewards value test : 0.9644743537854528 - best value : 0.9420405045405046
# 270/2000 - iteration : 3648 - rewards value test : 0.9461170675166619 - best value : 0.9644743537854528
# 280/2000 - iteration : 4211 - rewards value test : 0.9564404352445626 - best value : 0.9644743537854528
# 290/2000 - iteration : 4926 - rewards value test : 0.9810847380467633 - best value : 0.9644743537854528
# 300/2000 - iteration : 5983 - rewards value test : 0.9822316680909653 - best value : 0.9810847380467633
# 310/2000 - iteration : 7211 - rewards value test : 0.988507646315815 - best value : 0.9822316680909653
# 320/2000 - iteration : 8309 - rewards value test : 0.7555555555555555 - best value : 0.988507646315815
# 330/2000 - iteration : 9068 - rewards value test : 0.9781652656357294 - best value : 0.988507646315815
# 340/2000 - iteration : 10532 - rewards value test : 0.9817950377763461 - best value : 0.988507646315815
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_14520/4038629652.py in <module>
# ----> 1 cacla.learning()
#
# ~/Bureau/M2_ANDROIDE/M2_IAR/projet/tests/../utils/CACLAVAR.py in learning(self)
#      64                 state_t = torch.as_tensor(state , dtype=torch.float32)
#      65
# ---> 66                 action = self.get_action(state_t)
#      67
#      68                 new_state, reward, done = self.env.step(action)
#
# ~/Bureau/M2_ANDROIDE/M2_IAR/projet/tests/../utils/CACLAVAR.py in get_action(self, state_t)
#     131             return torch.as_tensor(
#     132                         np.array(
# --> 133                             np.random.normal(loc=self.actor_network(state_t).detach().numpy(),
#     134                             scale=self.sigma,size=(1,self.action_space))
#     135                         ),
#
# mtrand.pyx in numpy.random.mtrand.RandomState.normal()
#
# _common.pyx in numpy.random._common.cont()
#
# _common.pyx in numpy.random._common.cont_broadcast_2()
#
# _common.pyx in numpy.random._common.check_array_constraint()
#
# ~/.local/lib/python3.8/site-packages/numpy/core/overrides.py in any(*args, **kwargs)
#
# KeyboardInterrupt:

# %% [markdown]
# ## Affichage des rewards

# %%
inf = np.array(cacla.list_rewards_mean) - np.array(cacla.list_rewards_std)
sup = np.array(cacla.list_rewards_mean) + np.array(cacla.list_rewards_std)
plt.figure(figsize=(10,7))
plt.plot(np.arange(0,cacla.nb_episode,cacla.test_frequency),cacla.list_rewards_mean, c= 'r',label = 'rewards mean')
plt.fill_between(np.arange(0,cacla.nb_episode,cacla.test_frequency),inf,sup , color="mistyrose", label="rewards std")
plt.scatter(cacla.list_rewards_mean.index(max(cacla.list_rewards_mean))*cacla.test_frequency,max(cacla.list_rewards_mean),label="best reward : "+str(round(cacla.best_value,3)) )
plt.legend()
plt.xlabel('episode')
plt.ylabel('reward')
plt.title('Continuous Actor Critic (CACLA) - CartPoleContinuous - Rewards')
plt.show()

# %% [markdown]
# ## Démonstration de la simulation

# %%
env = ContinuousCartPoleEnv()
state = env.reset()
done = False
i = 0
cum_sum = 0.0
while not done :
    state_t = torch.as_tensor(state , dtype=torch.float32)
    action =  cacla.best_model(state_t).detach().numpy()
    new_state,reward,done = env.step(action)
    env.render()
    state = new_state
    cum_sum += reward
    i += 1
print(f"rewards cumulated : {cum_sum} and number iteration : {i}")
env.close()
# Out:
# rewards cumulated : 289.0 and number iteration : 291
