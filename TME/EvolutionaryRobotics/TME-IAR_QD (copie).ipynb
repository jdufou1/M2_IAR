# %% [markdown]
# # TME UE IAR: From Traditional EA to Quality-Diversity algorithms

# %% [markdown]
# Version du 26 novembre 2022

# %% [markdown]
# * Etudiant1: dufourmantelle jérémy
# * Etudiant2: abitbol ethan
#
# **Pour faciliter le suivi, merci à chaque membre du binome de soumettre le TME sous son nom.**

# %% [markdown]
# Cette séance de TME consiste à mettre en oeuvre des méthodes d'apprentissage de type "direct policy search" s'appuyant sur des algorithmes évolutionnaires.
#
# Ces algorithmes s'appuient sur des opérateurs de recherche stochastiques. Si vous lancez plusieurs fois une même expérience avec une graine aléatoire différente vous obtiendrez des résultats différents. Dans la mesure du possible et de la puissance de calcul que vous avez à disposition et s'il n'a pas été demandé explicitement de ne faire qu'une seule expérience, il est donc souhaitable de répéter les expériences plusieurs fois avant de conclure.
#
# Les cellules à compléter sont marquées <à compléter>.
#
# Vous prendrez soin de mettre des commentaires dans votre code et, pour chaque question, vous décrirez rapidement le travail réalisé. Vous prendrez soin de ne soumettre que les fichiers nécessaires (merci d'éviter les fichiers de log inutiles et de taille conséquente...).

# %% [markdown]
# ## 1. Introduction
#
# ### 1.1 Dépendances
#
# La seule dépendance nécessaire à ce TP est DEAP que vous pourrez installer de la façon suivante:

# %%
# !pip install deap
# !pip install plot
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: deap in /home/jdufou1/.local/lib/python3.8/site-packages (1.3.1)
# Requirement already satisfied: numpy in /home/jdufou1/.local/lib/python3.8/site-packages (from deap) (1.23.5)
# Defaulting to user installation because normal site-packages is not writeable
# Collecting plot
#   Downloading plot-0.6.5-py2.py3-none-any.whl (135 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 135.1/135.1 kB 3.0 MB/s eta 0:00:000:00:01
# Requirement already satisfied: scipy in /home/jdufou1/.local/lib/python3.8/site-packages (from plot) (1.7.1)
# Requirement already satisfied: matplotlib in /home/jdufou1/.local/lib/python3.8/site-packages (from plot) (3.4.3)
# Requirement already satisfied: pyyaml in /home/jdufou1/.local/lib/python3.8/site-packages (from plot) (6.0)
# Requirement already satisfied: numpy in /home/jdufou1/.local/lib/python3.8/site-packages (from plot) (1.23.5)
# Requirement already satisfied: typing in /home/jdufou1/.local/lib/python3.8/site-packages (from plot) (3.7.4.3)
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/lib/python3/dist-packages (from matplotlib->plot) (2.4.6)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/jdufou1/.local/lib/python3.8/site-packages (from matplotlib->plot) (1.3.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/lib/python3/dist-packages (from matplotlib->plot) (7.0.0)
# Requirement already satisfied: python-dateutil>=2.7 in /home/jdufou1/.local/lib/python3.8/site-packages (from matplotlib->plot) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in /home/jdufou1/.local/lib/python3.8/site-packages (from matplotlib->plot) (0.10.0)
# Collecting numpy
#   Using cached numpy-1.22.4-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.9 MB)
# Requirement already satisfied: six in /usr/lib/python3/dist-packages (from cycler>=0.10->matplotlib->plot) (1.14.0)
# Installing collected packages: numpy, plot
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.23.5
#     Uninstalling numpy-1.23.5:
#       Successfully uninstalled numpy-1.23.5
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# stable-baselines3 1.6.1 requires gym==0.21, but you have gym 0.18.3 which is incompatible.
# flappy-bird-gym 0.3.0 requires numpy~=1.19.5, but you have numpy 1.22.4 which is incompatible.
# Successfully installed numpy-1.22.4 plot-0.6.5

# %%
# Il n'y a rien à faire d'autre que d'exécuter cette cellule, 
# elle contient des imports qui vous seront utiles

# Note: l'import d'un fichier ne se fait qu'une seule fois. Si vous modifiez ce fichier, 
# il vous faut redémarrer votre kernel si vous voulez prendre en compte les modifications.
# vous pouvez éviter cela de la façon suivante: 
import importlib # une seule fois
import plot # le module doit avoir été importé une première fois
importlib.reload(plot) # cette ligne permet de charger la dernière version

import matplotlib.pyplot as plt

# pour que les figures apparaissent directement dans le notebook
# %matplotlib inline

# %% [markdown]
# ### 1.2 Environnement utilisé pour les expériences
#
# Vous allez utiliser un environnement simplifié pour permettre aux calculs d'être suffisamment rapides quelque soit votre environnement de travail. Il s'agit de la simulation d'un bras robotique articulé. Les paramètres explorés par l'algorithme évolutionnaire correspondent à l'angle que fait chaque segment par rapport au segment précédent. Il n'y a donc pas de politique à proprement parler.

# %%
from IPython.display import Image

fig = Image(filename=('bras.png'))
print("Représentation d'un bras à 3 degrés de liberté avec la cible et les obstacles qui seront utilisés dans la suite.")
fig
# Out:
# Représentation d'un bras à 3 degrés de liberté avec la cible et les obstacles qui seront utilisés dans la suite.

# %% [markdown]
# L'objectif des expériences est de déterminer les configurations du bras permettant d'atteindre diverses positions de l'espace avec l'effecteur terminal. Ces configurations peuvent être déterminées par le calcul, mais elles seront déterminées ici par l'algorithme évolutionnaire. Des obstacles ont été ajoutés dans l'environnement. La première partie du TP vise à atteindre la cible en rouge (avec un bras qui disposera de plus de segment que le bras représenté ici). La deuxième partie du TP vise à trouver des configurations du bras permettant d'atteindre l'ensemble des positions atteignables.

# %% [markdown]
# ## 2 Comparaison des expériences de Fit, NS et Fit+NS
#
# Cette première partie vise à vous faire prendre en main 3 variantes d'apprentissage direct dans l'espace des "politiques" (le terme de "politique" est ici un peu abusif, mais nous l'utiliserons tout de même dans la suite):
# - FIT: algorithme élitiste guidé par une fitness globale
# - NS: algorithme de recherche de nouveauté (novelty search)
# - FIT+NS: algorithme combinant FIT et NS avec une approche multi-objectif
#
# Vous regarderez attentivement le fichier ea_dps_ka.py et vous le compléterez pour afficher un message chaque fois qu'une politique améliore la fitness globale. A cette occasion, vous sauvegarderez la configuration de cet individu pour pouvoir la tracer ensuite dans les questions suivantes de ce notebook.

# %% [markdown]
# ### 2.1 Variante Fit
#
# Lancez quelques expériences avec la variante FIT. Tracez l'évolution de la fitness (opposé de la distance à la cible à maximiser) en fonction des générations et donnez les statistiques des résultats obtenus (combien d'expériences atteignent la cible, en combien de génération en moyenne). La cible sera considérée comme atteinte si l'effecteur terminal est à une distance de 0.5 ou moins de celle-ci. Vous tracerez également les configurations intermédiares du bras correspondant à des améliorations de la fitness (vous en tracerez une dizaime maximum pour ne pas surcharger le notebook).

# %%
# <à compléter>

# décrivez en quelques mots ce que vous avez fait, tracez les courbes d'évolution de la fitness, 
# indiquez les statistiques des résultats obtenus, les configurations intermédiaires et ajoutez un bref commentaire
# !python3 ea_dps_ka2.py
# Out:
# /home/jdufou1/.local/lib/python3.8/site-packages/scoop/fallbacks.py:38: RuntimeWarning: SCOOP was not started properly.
# Be sure to start your program with the '-m scoop' parameter. You can find further information in the documentation.
# Your map call has been replaced by the builtin serial Python map().
#   warnings.warn(
#   0%|                                                   | 0/100 [00:00<?, ?it/s]
# global fitness : -2.874388946703182
#   1%|▍                                          | 1/100 [00:00<00:19,  4.96it/s]
# global fitness : -2.1513040216480026
#   2%|▊                                          | 2/100 [00:00<00:19,  4.91it/s]
# global fitness : -1.7576152421901727
#   3%|█▎                                         | 3/100 [00:01<00:47,  2.04it/s]
# global fitness : -1.5930212957184235
#   4%|█▋                                         | 4/100 [00:02<00:58,  1.65it/s]
# global fitness : -1.4259552005919618
#   5%|██▏                                        | 5/100 [00:02<01:04,  1.47it/s]
# global fitness : -1.2708387870481863
#   6%|██▌                                        | 6/100 [00:03<01:06,  1.41it/s]
# global fitness : -1.2202551079092103
#   7%|███                                        | 7/100 [00:04<01:07,  1.39it/s]
# global fitness : -1.177359188858594
#   8%|███▍                                       | 8/100 [00:05<01:07,  1.36it/s]
# global fitness : -1.117842288275171
#   9%|███▊                                       | 9/100 [00:05<01:08,  1.33it/s]
# global fitness : -1.038382028853378
#  10%|████▏                                     | 10/100 [00:06<01:08,  1.31it/s]
# global fitness : -0.9609129869467217
#  11%|████▌                                     | 11/100 [00:07<01:07,  1.32it/s]
# global fitness : -0.8835376898101174
#  12%|█████                                     | 12/100 [00:08<01:06,  1.32it/s]
# global fitness : -0.8509318639093594
#  13%|█████▍                                    | 13/100 [00:08<01:07,  1.30it/s]
# global fitness : -0.7832126300767497
#  14%|█████▉                                    | 14/100 [00:09<01:08,  1.25it/s]
# global fitness : -0.7304413365319611
#  15%|██████▎                                   | 15/100 [00:10<01:09,  1.23it/s]
# global fitness : -0.6661271384711887
#  16%|██████▋                                   | 16/100 [00:11<01:06,  1.25it/s]
# global fitness : -0.6046260475473492
#  17%|███████▏                                  | 17/100 [00:12<01:05,  1.26it/s]
# global fitness : -0.5600577533726033
#  18%|███████▌                                  | 18/100 [00:13<01:04,  1.28it/s]
# global fitness : -0.496503080898552
#  19%|███████▉                                  | 19/100 [00:13<01:03,  1.28it/s]
# global fitness : -0.408239379522247
#  20%|████████▍                                 | 20/100 [00:14<01:03,  1.26it/s]
# global fitness : -0.3425281892855939
#  21%|████████▊                                 | 21/100 [00:15<01:03,  1.24it/s]
# global fitness : -0.2831648570358663
#  22%|█████████▏                                | 22/100 [00:16<01:01,  1.26it/s]
# global fitness : -0.20489542727229243
#  23%|█████████▋                                | 23/100 [00:17<01:01,  1.25it/s]
# global fitness : -0.15626379331448123
# ea_dps_ka2.py:483: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure(figsize=(10,7))
#  23%|█████████▋                                | 23/100 [00:21<01:13,  1.05it/s]
# Empty grid: no stats...
# Empty grid: no dump...

# %% [markdown]
# ### Affichage des configurations intermédiaires

# %% [markdown]
# Configuration intermédiaires avec une distance minimale de contact paramétrée à **0.2**.

# %% [markdown]
# ![config_24_1.png](attachment:511a021c-1236-445a-a415-e77936c7aab3.png)
# ![config_24_4.png](attachment:d03db85d-c5ce-4e40-8940-01ee7ec9d82a.png)
# ![config_24_5.png](attachment:66a9903c-d8a0-4fa7-8ece-24388cedc7f8.png)
# ![config_24_11.png](attachment:13ee6a5f-28db-4b08-b929-61908ea17303.png)
# ![config_24_16.png](attachment:91245e60-8b5c-41d9-af35-1d1c08a50949.png)
# ![config_24_19.png](attachment:730ba7e6-e12f-4328-b8f8-3b0d25843b33.png)
# ![config_24_23.png](attachment:c03219c5-5fe9-4a39-a275-df360d521dc5.png)

# %% [markdown]
# **Commentaire** : Après plusieurs tests, nous avons trouvé une execution ou la configuration du bras a 9 noeud atteint la cible en (-2,0). Nous constatons que les solutions trouvé entre les générations sont assez chaotiques mais évoluent dans le but de se rapprocher le plus possible de la cible, comme nous le voyons sur les clichés ci-dessus. Nous avons arreté de trouver des solutions lorsque la distance entre le bras et la cible est inférieur à **0.2**. Le dernier individu généré est celui de la génération **23**.

# %% [markdown]
# ### Résultats statistiques

# %%
# !python3 ea_dps_ka2.py
# Out:
#   0%|                                                    | 0/30 [00:00<?, ?it/s]/home/jdufou1/.local/lib/python3.8/site-packages/scoop/fallbacks.py:38: RuntimeWarning: SCOOP was not started properly.
# Be sure to start your program with the '-m scoop' parameter. You can find further information in the documentation.
# Your map call has been replaced by the builtin serial Python map().
#   warnings.warn(
# Empty grid: no stats...
# Empty grid: no dump...
#   3%|█▍                                          | 1/30 [01:14<36:00, 74.51s/it]Empty grid: no stats...
# Empty grid: no dump...
#   7%|██▉                                         | 2/30 [02:29<34:57, 74.90s/it]Empty grid: no stats...
# Empty grid: no dump...
#  10%|████▍                                       | 3/30 [03:44<33:46, 75.06s/it]Empty grid: no stats...
# Empty grid: no dump...
#  13%|█████▊                                      | 4/30 [05:00<32:40, 75.40s/it]Empty grid: no stats...
# Empty grid: no dump...
#  17%|███████▎                                    | 5/30 [06:13<30:57, 74.29s/it]Empty grid: no stats...
# Empty grid: no dump...
#  20%|████████▊                                   | 6/30 [07:26<29:34, 73.93s/it]Empty grid: no stats...
# Empty grid: no dump...
#  23%|██████████▎                                 | 7/30 [08:40<28:21, 73.96s/it]Empty grid: no stats...
# Empty grid: no dump...
#  27%|███████████▋                                | 8/30 [09:58<27:33, 75.14s/it]Empty grid: no stats...
# Empty grid: no dump...
#  30%|█████████████▏                              | 9/30 [11:16<26:42, 76.29s/it]Empty grid: no stats...
# Empty grid: no dump...
#  33%|██████████████▎                            | 10/30 [12:30<25:07, 75.37s/it]Empty grid: no stats...
# Empty grid: no dump...
#  37%|███████████████▊                           | 11/30 [13:31<22:32, 71.21s/it]Empty grid: no stats...
# Empty grid: no dump...
#  40%|█████████████████▏                         | 12/30 [14:34<20:35, 68.65s/it]Empty grid: no stats...
# Empty grid: no dump...
#  43%|██████████████████▋                        | 13/30 [15:37<18:55, 66.78s/it]Empty grid: no stats...
# Empty grid: no dump...
#  47%|████████████████████                       | 14/30 [16:39<17:24, 65.29s/it]Empty grid: no stats...
# Empty grid: no dump...
#  50%|█████████████████████▌                     | 15/30 [17:40<16:03, 64.21s/it]Empty grid: no stats...
# Empty grid: no dump...
#  53%|██████████████████████▉                    | 16/30 [18:42<14:48, 63.49s/it]Empty grid: no stats...
# Empty grid: no dump...
#  57%|████████████████████████▎                  | 17/30 [19:44<13:40, 63.15s/it]Empty grid: no stats...
# Empty grid: no dump...
#  60%|█████████████████████████▊                 | 18/30 [20:46<12:32, 62.72s/it]Empty grid: no stats...
# Empty grid: no dump...
#  63%|███████████████████████████▏               | 19/30 [21:48<11:26, 62.41s/it]Empty grid: no stats...
# Empty grid: no dump...
#  67%|████████████████████████████▋              | 20/30 [22:50<10:23, 62.33s/it]Empty grid: no stats...
# Empty grid: no dump...
#  70%|██████████████████████████████             | 21/30 [23:52<09:19, 62.14s/it]Empty grid: no stats...
# Empty grid: no dump...
#  73%|███████████████████████████████▌           | 22/30 [24:54<08:16, 62.03s/it]Empty grid: no stats...
# Empty grid: no dump...
#  77%|████████████████████████████████▉          | 23/30 [25:55<07:13, 61.93s/it]Empty grid: no stats...
# Empty grid: no dump...
#  80%|██████████████████████████████████▍        | 24/30 [26:57<06:11, 61.86s/it]Empty grid: no stats...
# Empty grid: no dump...
#  83%|███████████████████████████████████▊       | 25/30 [27:59<05:08, 61.79s/it]Empty grid: no stats...
# Empty grid: no dump...
#  87%|█████████████████████████████████████▎     | 26/30 [29:00<04:06, 61.67s/it]Empty grid: no stats...
# Empty grid: no dump...
#  90%|██████████████████████████████████████▋    | 27/30 [30:02<03:04, 61.64s/it]Empty grid: no stats...
# Empty grid: no dump...
#  93%|████████████████████████████████████████▏  | 28/30 [31:03<02:03, 61.67s/it]Empty grid: no stats...
# Empty grid: no dump...
#  97%|█████████████████████████████████████████▌ | 29/30 [32:05<01:01, 61.70s/it]Empty grid: no stats...
# Empty grid: no dump...
# 100%|███████████████████████████████████████████| 30/30 [33:07<00:00, 66.24s/it]
# resultats success : 11/30 = 36.666666666666664%
# resultats fails : 19/30 = 63.33333333333333%
# resultats convergence moyenne de 13.818181818181818 génération sur 11 echantillons

# %% [markdown]
# ### 2.2 Variante NS
#
# Mêmes questions avec la variante NS.

# %% [markdown]
# ### Affichage des configurations intermédiaires

# %% [markdown]
# Configuration intermédiaires avec une distance minimale de contact paramétrée à **0.5**.

# %%
# <à compléter>

# décrivez en quelques mots ce que vous avez fait, tracez les courbes d'évolution de la fitness, 
# indiquez les statistiques des résultats obtenus, les configurations intermédiaires et ajoutez un bref commentaire
# !python3 -m scoop ea_dps_ka2.py
# Out:
# [2022-12-04 22:50:43,562] launcher  INFO    SCOOP 0.7 1.1 on linux using Python 3.8.10 (default, Jun 22 2022, 20:18:18) [GCC 9.4.0], API: 1013
# [2022-12-04 22:50:43,563] launcher  INFO    Deploying 4 worker(s) over 1 host(s).
# [2022-12-04 22:50:43,563] launcher  INFO    Worker distribution:
# [2022-12-04 22:50:43,563] launcher  INFO       127.0.0.1:	3 + origin
# /home/jdufou1/.local/lib/python3.8/site-packages/deap/creator.py:138: RuntimeWarning: A class named 'MyFitness' has already been created and it will be overwritten. Consider deleting previous creation of that class or rename it.
#   warnings.warn("A class named '{0}' has already been created and it "
# /home/jdufou1/.local/lib/python3.8/site-packages/deap/creator.py:138: RuntimeWarning: A class named 'Individual' has already been created and it will be overwritten. Consider deleting previous creation of that class or rename it.
#   warnings.warn("A class named '{0}' has already been created and it "
# /home/jdufou1/.local/lib/python3.8/site-packages/deap/creator.py:138: RuntimeWarning: A class named 'Strategy' has already been created and it will be overwritten. Consider deleting previous creation of that class or rename it.
#   warnings.warn("A class named '{0}' has already been created and it "
#
# génération 1 - global fitness : -3.0864803947560984
#
# génération 2 - global fitness : -2.202326947030907
#
# génération 3 - global fitness : -2.9819154135994
#
# génération 4 - global fitness : -2.7517507097132277
#
# génération 5 - global fitness : -2.6893763622630433
#
# génération 6 - global fitness : -2.9262312858208173
#
# génération 7 - global fitness : -3.0202563175479247
#
# génération 8 - global fitness : -3.614677190836582
#
# génération 9 - global fitness : -3.41161140793993
#
# génération 10 - global fitness : -4.1739315184850225
#
# génération 11 - global fitness : -3.9465933515584597
#
# génération 12 - global fitness : -3.0874364636062444
#
# génération 13 - global fitness : -3.8358439669339037
#
# génération 14 - global fitness : -3.5952094997836053
#
# génération 15 - global fitness : -3.6452544627535515
#
# génération 16 - global fitness : -3.505308130496138
#
# génération 17 - global fitness : -3.115825296408577
#
# génération 18 - global fitness : -2.994546735532748
#
# génération 19 - global fitness : -2.777175457055827
#
# génération 20 - global fitness : -3.4535969503258372
#
# génération 21 - global fitness : -3.036452348892703
#
# génération 22 - global fitness : -2.671758180053027
#
# génération 23 - global fitness : -2.687611389810627
#
# génération 24 - global fitness : -2.434190458593171
#
# génération 25 - global fitness : -2.369186743179344
#
# génération 26 - global fitness : -2.6193486226964184
#
# génération 27 - global fitness : -2.501868220663995
#
# génération 28 - global fitness : -1.3876554090099822
#
# génération 29 - global fitness : -1.4998830221935382
#
# génération 30 - global fitness : -1.6300558148511572
#
# génération 31 - global fitness : -1.5100931035204763
#
# génération 32 - global fitness : -1.8503790672977607
#
# génération 33 - global fitness : -1.589691444738063
#
# génération 34 - global fitness : -1.6416936321419078
#
# génération 35 - global fitness : -1.9078273400655832
#
# génération 36 - global fitness : -2.048117638159694
#
# génération 37 - global fitness : -1.995032780171326
#
# génération 38 - global fitness : -1.6035337126387168
#
# génération 39 - global fitness : -1.3595068663015655
#
# génération 40 - global fitness : -1.1493938392298673
#
# génération 41 - global fitness : -0.4447110051796782
# ea_dps_ka2.py:484: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure(figsize=(10,7))
# Empty grid: no stats...
# Empty grid: no dump...
# [2022-12-04 22:51:23,312] launcher  (127.0.0.1:43501) INFO    Root process is done.
# [2022-12-04 22:51:23,313] launcher  (127.0.0.1:43501) INFO    Finished cleaning spawned subprocesses.

# %% [markdown]
# ![config_41_1.png](attachment:24934ad3-83be-46f8-b7a2-7408aaf6d329.png)
# ![config_41_5.png](attachment:a7cadf3a-7146-4116-a9db-4479a271e055.png)
# ![config_41_10.png](attachment:35d8c2d3-8add-45c5-88df-5484bc59e7f8.png)
# ![config_41_15.png](attachment:b6f13d16-f54d-41a4-84c9-39db178bc494.png)
# ![config_41_20.png](attachment:dc628de9-45e8-4375-acd0-68f9ea0cd3f2.png)
# ![config_41_25.png](attachment:56c3fedd-4a0f-4fc0-aaa8-684d9732e3c1.png)
# ![config_41_30.png](attachment:6aa7495a-292f-41b0-936b-7da5b401d90d.png)
# ![config_41_35.png](attachment:7cad6b60-16cc-4252-9cab-82df5659469a.png)
# ![config_41_40.png](attachment:15eed607-8ab2-4066-a3cc-5a71c6441013.png)

# %% [markdown]
# **Commentaire** :

# %% [markdown]
# ### Résultat statistiques

# %%
# !python3 -m scoop ea_dps_ka2.py
# Out:
# [2022-12-09 00:41:32,051] launcher  INFO    SCOOP 0.7 1.1 on linux using Python 3.8.10 (default, Jun 22 2022, 20:18:18) [GCC 9.4.0], API: 1013
# [2022-12-09 00:41:32,051] launcher  INFO    Deploying 4 worker(s) over 1 host(s).
# [2022-12-09 00:41:32,051] launcher  INFO    Worker distribution:
# [2022-12-09 00:41:32,051] launcher  INFO       127.0.0.1:	3 + origin
# /home/jdufou1/.local/lib/python3.8/site-packages/deap/creator.py:138: RuntimeWarning: A class named 'MyFitness' has already been created and it will be overwritten. Consider deleting previous creation of that class or rename it.
#   warnings.warn("A class named '{0}' has already been created and it "
# /home/jdufou1/.local/lib/python3.8/site-packages/deap/creator.py:138: RuntimeWarning: A class named 'Individual' has already been created and it will be overwritten. Consider deleting previous creation of that class or rename it.
#   warnings.warn("A class named '{0}' has already been created and it "
# /home/jdufou1/.local/lib/python3.8/site-packages/deap/creator.py:138: RuntimeWarning: A class named 'Strategy' has already been created and it will be overwritten. Consider deleting previous creation of that class or rename it.
#   warnings.warn("A class named '{0}' has already been created and it "
#   0%|                                                    | 0/30 [00:00<?, ?it/s]Empty grid: no stats...
# Empty grid: no dump...
#   3%|█▍                                          | 1/30 [00:59<28:56, 59.88s/it]Empty grid: no stats...
# Empty grid: no dump...
#   7%|██▉                                         | 2/30 [01:45<24:05, 51.61s/it]Empty grid: no stats...
# Empty grid: no dump...
#  10%|████▍                                       | 3/30 [02:28<21:30, 47.81s/it]Empty grid: no stats...
# Empty grid: no dump...
#  13%|█████▊                                      | 4/30 [03:18<21:03, 48.61s/it]Empty grid: no stats...
# Empty grid: no dump...
#  17%|███████▎                                    | 5/30 [03:57<18:43, 44.95s/it]Empty grid: no stats...
# Empty grid: no dump...
#  20%|████████▊                                   | 6/30 [04:55<19:43, 49.30s/it]Empty grid: no stats...
# Empty grid: no dump...
#  23%|██████████▎                                 | 7/30 [05:39<18:17, 47.72s/it]Empty grid: no stats...
# Empty grid: no dump...
#  27%|███████████▋                                | 8/30 [06:40<19:00, 51.83s/it]Empty grid: no stats...
# Empty grid: no dump...
#  30%|█████████████▏                              | 9/30 [07:45<19:35, 55.99s/it]Empty grid: no stats...
# Empty grid: no dump...
#  33%|██████████████▎                            | 10/30 [08:41<18:40, 56.03s/it]Empty grid: no stats...
# Empty grid: no dump...
#  37%|███████████████▊                           | 11/30 [09:35<17:33, 55.47s/it]Empty grid: no stats...
# Empty grid: no dump...
#  40%|█████████████████▏                         | 12/30 [10:12<14:55, 49.73s/it]Empty grid: no stats...
# Empty grid: no dump...
#  43%|██████████████████▋                        | 13/30 [11:23<15:54, 56.16s/it]Empty grid: no stats...
# Empty grid: no dump...
#  47%|████████████████████                       | 14/30 [12:24<15:23, 57.74s/it]Empty grid: no stats...
# Empty grid: no dump...
#  50%|█████████████████████▌                     | 15/30 [13:19<14:15, 57.02s/it]Empty grid: no stats...
# Empty grid: no dump...
#  53%|██████████████████████▉                    | 16/30 [14:19<13:27, 57.68s/it]Empty grid: no stats...
# Empty grid: no dump...
#  57%|████████████████████████▎                  | 17/30 [15:46<14:27, 66.74s/it]Empty grid: no stats...
# Empty grid: no dump...
#  60%|█████████████████████████▊                 | 18/30 [17:06<14:08, 70.69s/it]Empty grid: no stats...
# Empty grid: no dump...
#  63%|███████████████████████████▏               | 19/30 [17:55<11:43, 63.99s/it]Empty grid: no stats...
# Empty grid: no dump...
#  67%|████████████████████████████▋              | 20/30 [19:16<11:32, 69.22s/it]Empty grid: no stats...
# Empty grid: no dump...
#  70%|██████████████████████████████             | 21/30 [19:56<09:03, 60.35s/it]Empty grid: no stats...
# Empty grid: no dump...
#  73%|███████████████████████████████▌           | 22/30 [20:52<07:52, 59.11s/it]Empty grid: no stats...
# Empty grid: no dump...
#  77%|████████████████████████████████▉          | 23/30 [22:06<07:25, 63.62s/it]Empty grid: no stats...
# Empty grid: no dump...
#  80%|██████████████████████████████████▍        | 24/30 [22:47<05:40, 56.83s/it]Empty grid: no stats...
# Empty grid: no dump...
#  83%|███████████████████████████████████▊       | 25/30 [23:20<04:08, 49.77s/it]Empty grid: no stats...
# Empty grid: no dump...
#  87%|█████████████████████████████████████▎     | 26/30 [24:01<03:08, 47.13s/it]Empty grid: no stats...
# Empty grid: no dump...
#  90%|██████████████████████████████████████▋    | 27/30 [24:44<02:17, 45.91s/it]Empty grid: no stats...
# Empty grid: no dump...
#  93%|████████████████████████████████████████▏  | 28/30 [26:06<01:53, 56.66s/it]Empty grid: no stats...
# Empty grid: no dump...
#  97%|█████████████████████████████████████████▌ | 29/30 [26:38<00:49, 49.17s/it]Empty grid: no stats...
# Empty grid: no dump...
# 100%|███████████████████████████████████████████| 30/30 [27:17<00:00, 54.57s/it]
# resultats success : 30/30 = 100.0%
# resultats fails : 0/30 = 0.0%
# resultats convergence moyenne de 99.03333333333333 génération sur 30 echantillons
# [2022-12-09 01:08:51,036] launcher  (127.0.0.1:37521) INFO    Root process is done.
# [2022-12-09 01:08:51,037] launcher  (127.0.0.1:37521) INFO    Finished cleaning spawned subprocesses.

# %% [markdown]
# ### 2.3 Variante FIT+NS
#
# Mêmes questions avec la variante qui utilise 2 objectifs: Fitness et Novelty (variante FIT+NS).

# %%
# !python3 -m scoop ea_dps_ka2.py
# Out:
# [2022-12-08 22:14:33,328] launcher  INFO    SCOOP 0.7 1.1 on linux using Python 3.8.10 (default, Jun 22 2022, 20:18:18) [GCC 9.4.0], API: 1013
# [2022-12-08 22:14:33,328] launcher  INFO    Deploying 4 worker(s) over 1 host(s).
# [2022-12-08 22:14:33,328] launcher  INFO    Worker distribution:
# [2022-12-08 22:14:33,328] launcher  INFO       127.0.0.1:	3 + origin
# /home/jdufou1/.local/lib/python3.8/site-packages/deap/creator.py:138: RuntimeWarning: A class named 'MyFitness' has already been created and it will be overwritten. Consider deleting previous creation of that class or rename it.
#   warnings.warn("A class named '{0}' has already been created and it "
# /home/jdufou1/.local/lib/python3.8/site-packages/deap/creator.py:138: RuntimeWarning: A class named 'Individual' has already been created and it will be overwritten. Consider deleting previous creation of that class or rename it.
#   warnings.warn("A class named '{0}' has already been created and it "
# /home/jdufou1/.local/lib/python3.8/site-packages/deap/creator.py:138: RuntimeWarning: A class named 'Strategy' has already been created and it will be overwritten. Consider deleting previous creation of that class or rename it.
#   warnings.warn("A class named '{0}' has already been created and it "
#
# génération 1 - global fitness : -2.8306014299497444
#
# génération 2 - global fitness : -2.00729193958557
#
# génération 3 - global fitness : -2.5196103508202174
#
# génération 4 - global fitness : -3.2384714234052843
#
# génération 5 - global fitness : -2.909875669498459
#
# génération 6 - global fitness : -3.591720363176787
#
# génération 7 - global fitness : -3.722402658838197
#
# génération 8 - global fitness : -3.7956524948837913
#
# génération 9 - global fitness : -3.6620631059137865
#
# génération 10 - global fitness : -3.154721601654091
#
# génération 11 - global fitness : -3.1603185797040787
#
# génération 12 - global fitness : -3.5782579435578517
#
# génération 13 - global fitness : -4.267851344449941
#
# génération 14 - global fitness : -3.33554773726787
#
# génération 15 - global fitness : -2.637252229971174
#
# génération 16 - global fitness : -2.7419035597721666
#
# génération 17 - global fitness : -2.582876287015543
#
# génération 18 - global fitness : -2.716686039111768
#
# génération 19 - global fitness : -1.4833330546395742
#
# génération 20 - global fitness : -2.0235903648889173
#
# génération 21 - global fitness : -1.5812165672984668
#
# génération 22 - global fitness : -1.3702769527875995
#
# génération 23 - global fitness : -2.2632504676272513
#
# génération 24 - global fitness : -2.0572237556793764
#
# génération 25 - global fitness : -2.4932392883474335
#
# génération 26 - global fitness : -2.0301520454985775
#
# génération 27 - global fitness : -2.2783853663200704
#
# génération 28 - global fitness : -1.9055843481369248
#
# génération 29 - global fitness : -1.830561534935293
#
# génération 30 - global fitness : -1.5983842736358007
#
# génération 31 - global fitness : -1.4869967105792323
#
# génération 32 - global fitness : -1.5605454871850648
#
# génération 33 - global fitness : -1.3679259896951188
#
# génération 34 - global fitness : -1.5133937038515186
#
# génération 35 - global fitness : -0.9679225460806361
#
# génération 36 - global fitness : -1.2399102734628165
#
# génération 37 - global fitness : -1.3672967770103233
#
# génération 38 - global fitness : -1.3969372494761825
#
# génération 39 - global fitness : -1.6069858303272742
#
# génération 40 - global fitness : -2.226986292307391
#
# génération 41 - global fitness : -1.3415113837503745
#
# génération 42 - global fitness : -1.4711806861339531
#
# génération 43 - global fitness : -1.6798848253801877
#
# génération 44 - global fitness : -1.412824458899134
#
# génération 45 - global fitness : -1.8479222743932968
#
# génération 46 - global fitness : -1.4805944663376605
#
# génération 47 - global fitness : -1.8510468702096687
#
# génération 48 - global fitness : -1.3734554343959688
#
# génération 49 - global fitness : -1.2767521934418078
#
# génération 50 - global fitness : -1.6105631294057656
#
# génération 51 - global fitness : -1.2896437485730075
#
# génération 52 - global fitness : -1.3296069555400152
#
# génération 53 - global fitness : -1.7380306850003453
#
# génération 54 - global fitness : -1.1483845707341849
#
# génération 55 - global fitness : -0.8491489084693895
#
# génération 56 - global fitness : -1.3713173980973423
#
# génération 57 - global fitness : -1.1414330290968104
#
# génération 58 - global fitness : -1.1821233330234917
#
# génération 59 - global fitness : -1.1642276391869106
#
# génération 60 - global fitness : -1.2841191556822016
#
# génération 61 - global fitness : -1.3070366030257807
#
# génération 62 - global fitness : -2.0352452784653043
#
# génération 63 - global fitness : -1.6361865528123636
#
# génération 64 - global fitness : -1.7353989763434767
#
# génération 65 - global fitness : -1.6165020306186206
#
# génération 66 - global fitness : -1.0610533105250752
#
# génération 67 - global fitness : -1.272953881925841
#
# génération 68 - global fitness : -1.1808165286806098
#
# génération 69 - global fitness : -0.948867296407306
#
# génération 70 - global fitness : -0.7572454027641927
#
# génération 71 - global fitness : -0.8610625236544481
#
# génération 72 - global fitness : -0.8042076028369942
#
# génération 73 - global fitness : -0.7238548320906502
#
# génération 74 - global fitness : -1.0021320480902105
#
# génération 75 - global fitness : -1.0843455614288606
#
# génération 76 - global fitness : -0.992671831280871
#
# génération 77 - global fitness : -0.697235034713256
#
# génération 78 - global fitness : -0.7956875095763728
#
# génération 79 - global fitness : -0.7793513722943552
#
# génération 80 - global fitness : -0.9943310512182875
#
# génération 81 - global fitness : -0.942564896202777
#
# génération 82 - global fitness : -1.056049485878556
#
# génération 83 - global fitness : -0.8635635912558345
#
# génération 84 - global fitness : -0.4531208600259938
# ea_dps_ka2.py:485: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure(figsize=(10,7))
# Empty grid: no stats...
# Empty grid: no dump...
# [2022-12-08 22:15:59,677] launcher  (127.0.0.1:38289) INFO    Root process is done.
# [2022-12-08 22:15:59,678] launcher  (127.0.0.1:38289) INFO    Finished cleaning spawned subprocesses.

# %% [markdown]
# ## Affichage des configurations intermediaire

# %% [markdown]
# ![config_84_0.png](attachment:f608ddd3-1616-4bda-a210-3419ff626be1.png)
# ![config_84_5.png](attachment:58767575-d8b8-4b99-bd17-5e853e8a860f.png)
# ![config_84_10.png](attachment:9cfb08b3-df81-4454-bb83-e840d6881526.png)
# ![config_84_20.png](attachment:13037d8a-d003-4253-a901-9e6afcb40fd5.png)
# ![config_84_30.png](attachment:375ce936-28d7-4f1c-ad1e-268d01ed81e0.png)
# ![config_84_50.png](attachment:aaaf96a2-7407-4484-90b2-e99593bfc3cf.png)
# ![config_84_60.png](attachment:22c5f32d-db85-44c9-b8ac-ce2a2fe6c0c7.png)
# ![config_84_83.png](attachment:ff40f1a3-d424-4caf-8638-03b2fc6406e3.png)

# %% [markdown]
# ### Résultat statistiques

# %%
# !python3 -m scoop ea_dps_ka2.py
# Out:
# [2022-12-04 22:55:25,912] launcher  INFO    SCOOP 0.7 1.1 on linux using Python 3.8.10 (default, Jun 22 2022, 20:18:18) [GCC 9.4.0], API: 1013
# [2022-12-04 22:55:25,912] launcher  INFO    Deploying 4 worker(s) over 1 host(s).
# [2022-12-04 22:55:25,912] launcher  INFO    Worker distribution:
# [2022-12-04 22:55:25,913] launcher  INFO       127.0.0.1:	3 + origin
# /home/jdufou1/.local/lib/python3.8/site-packages/deap/creator.py:138: RuntimeWarning: A class named 'MyFitness' has already been created and it will be overwritten. Consider deleting previous creation of that class or rename it.
#   warnings.warn("A class named '{0}' has already been created and it "
# /home/jdufou1/.local/lib/python3.8/site-packages/deap/creator.py:138: RuntimeWarning: A class named 'Individual' has already been created and it will be overwritten. Consider deleting previous creation of that class or rename it.
#   warnings.warn("A class named '{0}' has already been created and it "
# /home/jdufou1/.local/lib/python3.8/site-packages/deap/creator.py:138: RuntimeWarning: A class named 'Strategy' has already been created and it will be overwritten. Consider deleting previous creation of that class or rename it.
#   warnings.warn("A class named '{0}' has already been created and it "
#   0%|                                                    | 0/30 [00:00<?, ?it/s]Empty grid: no stats...
# Empty grid: no dump...
#   3%|█▍                                          | 1/30 [01:18<37:57, 78.52s/it]Empty grid: no stats...
# Empty grid: no dump...
#   7%|██▉                                         | 2/30 [02:37<36:39, 78.56s/it]Empty grid: no stats...
# Empty grid: no dump...
#  10%|████▍                                       | 3/30 [03:52<34:37, 76.94s/it]Empty grid: no stats...
# Empty grid: no dump...
#  13%|█████▊                                      | 4/30 [05:05<32:46, 75.62s/it]Empty grid: no stats...
# Empty grid: no dump...
#  17%|███████▎                                    | 5/30 [06:18<31:06, 74.65s/it]Empty grid: no stats...
# Empty grid: no dump...
#  20%|████████▊                                   | 6/30 [07:43<31:13, 78.06s/it]Empty grid: no stats...
# Empty grid: no dump...
#  23%|██████████▎                                 | 7/30 [09:07<30:42, 80.12s/it]Empty grid: no stats...
# Empty grid: no dump...
#  27%|███████████▋                                | 8/30 [10:18<28:17, 77.15s/it]Empty grid: no stats...
# Empty grid: no dump...
#  30%|█████████████▏                              | 9/30 [11:27<26:06, 74.61s/it]Empty grid: no stats...
# Empty grid: no dump...
#  33%|██████████████▎                            | 10/30 [12:35<24:13, 72.69s/it]Empty grid: no stats...
# Empty grid: no dump...
#  37%|███████████████▊                           | 11/30 [13:44<22:35, 71.37s/it]Empty grid: no stats...
# Empty grid: no dump...
#  40%|█████████████████▏                         | 12/30 [14:52<21:09, 70.51s/it]Empty grid: no stats...
# Empty grid: no dump...
#  43%|██████████████████▋                        | 13/30 [16:01<19:49, 69.96s/it]Empty grid: no stats...
# Empty grid: no dump...
#  47%|████████████████████                       | 14/30 [17:10<18:33, 69.59s/it]Empty grid: no stats...
# Empty grid: no dump...
#  50%|█████████████████████▌                     | 15/30 [18:18<17:18, 69.24s/it]Empty grid: no stats...
# Empty grid: no dump...
#  53%|██████████████████████▉                    | 16/30 [19:27<16:06, 69.05s/it]Empty grid: no stats...
# Empty grid: no dump...
#  57%|████████████████████████▎                  | 17/30 [20:35<14:55, 68.91s/it]Empty grid: no stats...
# Empty grid: no dump...
#  60%|█████████████████████████▊                 | 18/30 [21:44<13:45, 68.82s/it]Empty grid: no stats...
# Empty grid: no dump...
#  63%|███████████████████████████▏               | 19/30 [22:52<12:35, 68.66s/it]Empty grid: no stats...
# Empty grid: no dump...
#  67%|████████████████████████████▋              | 20/30 [24:01<11:26, 68.63s/it]Empty grid: no stats...
# Empty grid: no dump...
#  70%|██████████████████████████████             | 21/30 [25:10<10:18, 68.78s/it]Empty grid: no stats...
# Empty grid: no dump...
#  73%|███████████████████████████████▌           | 22/30 [26:19<09:11, 68.92s/it]Empty grid: no stats...
# Empty grid: no dump...
#  77%|████████████████████████████████▉          | 23/30 [27:28<08:02, 68.88s/it]Empty grid: no stats...
# Empty grid: no dump...
#  80%|██████████████████████████████████▍        | 24/30 [28:37<06:53, 68.90s/it]Empty grid: no stats...
# Empty grid: no dump...
#  83%|███████████████████████████████████▊       | 25/30 [29:46<05:44, 68.98s/it]Empty grid: no stats...
# Empty grid: no dump...
#  87%|█████████████████████████████████████▎     | 26/30 [30:54<04:34, 68.63s/it]Empty grid: no stats...
# Empty grid: no dump...
#  90%|██████████████████████████████████████▋    | 27/30 [32:10<03:32, 70.99s/it]Empty grid: no stats...
# Empty grid: no dump...
#  93%|████████████████████████████████████████▏  | 28/30 [33:24<02:23, 71.89s/it]Empty grid: no stats...
# Empty grid: no dump...
#  97%|█████████████████████████████████████████▌ | 29/30 [34:34<01:11, 71.31s/it]Empty grid: no stats...
# Empty grid: no dump...
# 100%|███████████████████████████████████████████| 30/30 [35:44<00:00, 71.48s/it]
# resultats success : 16/30 = 53.333333333333336%
# resultats fails : 14/30 = 46.666666666666664%
# resultats convergence moyenne de 78.25 génération sur 16 echantillons
# [2022-12-04 23:31:12,055] launcher  (127.0.0.1:41749) INFO    Root process is done.
# [2022-12-04 23:31:12,055] launcher  (127.0.0.1:41749) INFO    Finished cleaning spawned subprocesses.

# %% [markdown]
# ## 3 Diversité des comportements générés

# %% [markdown]
# La position finale de chaque point généré est enregistrée dans le fichier bd.log. Tracez ces différents points sur une même figure pour une experience de NS, de FIT et de FIT+NS. Qu'en déduisez-vous sur la capacité d'exploration de chacun de ces algorithmes ?

# %%
# !python3 -m scoop ea_dps_ka2.py
# Out:
# [2022-12-08 22:43:28,630] launcher  INFO    SCOOP 0.7 1.1 on linux using Python 3.8.10 (default, Jun 22 2022, 20:18:18) [GCC 9.4.0], API: 1013
# [2022-12-08 22:43:28,630] launcher  INFO    Deploying 4 worker(s) over 1 host(s).
# [2022-12-08 22:43:28,630] launcher  INFO    Worker distribution:
# [2022-12-08 22:43:28,630] launcher  INFO       127.0.0.1:	3 + origin
# /home/jdufou1/.local/lib/python3.8/site-packages/deap/creator.py:138: RuntimeWarning: A class named 'MyFitness' has already been created and it will be overwritten. Consider deleting previous creation of that class or rename it.
#   warnings.warn("A class named '{0}' has already been created and it "
# /home/jdufou1/.local/lib/python3.8/site-packages/deap/creator.py:138: RuntimeWarning: A class named 'Individual' has already been created and it will be overwritten. Consider deleting previous creation of that class or rename it.
#   warnings.warn("A class named '{0}' has already been created and it "
# /home/jdufou1/.local/lib/python3.8/site-packages/deap/creator.py:138: RuntimeWarning: A class named 'Strategy' has already been created and it will be overwritten. Consider deleting previous creation of that class or rename it.
#   warnings.warn("A class named '{0}' has already been created and it "
#
# génération 1 - global fitness : -2.962489941421434
#
# génération 2 - global fitness : -2.198760756464846
#
# génération 3 - global fitness : -2.794550280371598
#
# génération 4 - global fitness : -2.8874112275865076
#
# génération 5 - global fitness : -2.948711160723937
#
# génération 6 - global fitness : -3.572709882183679
#
# génération 7 - global fitness : -3.769969742299707
#
# génération 8 - global fitness : -2.9948042743894745
#
# génération 9 - global fitness : -3.090650847572457
#
# génération 10 - global fitness : -3.6237202974932625
#
# génération 11 - global fitness : -3.5972826771239146
#
# génération 12 - global fitness : -3.4342157520303633
#
# génération 13 - global fitness : -3.5959141802509595
#
# génération 14 - global fitness : -4.126900312397769
#
# génération 15 - global fitness : -4.481158674286063
#
# génération 16 - global fitness : -4.080759211653601
#
# génération 17 - global fitness : -3.635113583492823
#
# génération 18 - global fitness : -3.148596922269312
#
# génération 19 - global fitness : -3.193998895792614
#
# génération 20 - global fitness : -2.459704857067054
#
# génération 21 - global fitness : -3.4168088235106833
#
# génération 22 - global fitness : -3.1237279456173077
#
# génération 23 - global fitness : -3.1135400102785926
#
# génération 24 - global fitness : -3.4062896204738764
#
# génération 25 - global fitness : -4.014804439545105
#
# génération 26 - global fitness : -3.180006832937518
#
# génération 27 - global fitness : -2.786557522894075
#
# génération 28 - global fitness : -2.3450921044746824
#
# génération 29 - global fitness : -2.570223592499011
#
# génération 30 - global fitness : -3.0918332622313986
#
# génération 31 - global fitness : -2.944558760607626
#
# génération 32 - global fitness : -1.9599712768938147
#
# génération 33 - global fitness : -2.367576372763149
#
# génération 34 - global fitness : -2.9770172413412737
#
# génération 35 - global fitness : -1.6435608817113962
#
# génération 36 - global fitness : -3.0833142226229744
#
# génération 37 - global fitness : -3.86764541639713
#
# génération 38 - global fitness : -2.60972578578782
#
# génération 39 - global fitness : -3.09573463164718
#
# génération 40 - global fitness : -2.59658901880765
#
# génération 41 - global fitness : -3.695357927602097
#
# génération 42 - global fitness : -3.1084495164516075
#
# génération 43 - global fitness : -3.505097125798826
#
# génération 44 - global fitness : -3.286177391873806
#
# génération 45 - global fitness : -3.5712292002222705
#
# génération 46 - global fitness : -2.932359267847487
#
# génération 47 - global fitness : -2.558496883771996
#
# génération 48 - global fitness : -2.8215952239003674
#
# génération 49 - global fitness : -2.374526375792602
#
# génération 50 - global fitness : -1.6766263662956273
#
# génération 51 - global fitness : -3.0700742836454418
#
# génération 52 - global fitness : -2.4360668797410536
#
# génération 53 - global fitness : -2.9764370288780704
#
# génération 54 - global fitness : -2.2967308260704296
#
# génération 55 - global fitness : -2.6933373603408723
#
# génération 56 - global fitness : -3.383757734736964
#
# génération 57 - global fitness : -2.5154654985432416
#
# génération 58 - global fitness : -3.5599317950187013
#
# génération 59 - global fitness : -2.996939864676142
#
# génération 60 - global fitness : -3.037284272116172
#
# génération 61 - global fitness : -2.633212264399368
#
# génération 62 - global fitness : -2.7334612136948766
#
# génération 63 - global fitness : -2.01504916090788
#
# génération 64 - global fitness : -1.9416404738917583
#
# génération 65 - global fitness : -3.1982856555804147
#
# génération 66 - global fitness : -3.054321573369957
#
# génération 67 - global fitness : -2.5699432941449127
#
# génération 68 - global fitness : -1.9479852116158325
#
# génération 69 - global fitness : -3.3454416814487535
#
# génération 70 - global fitness : -3.1869132538962917
#
# génération 71 - global fitness : -3.325453464412494
#
# génération 72 - global fitness : -3.058019472207261
#
# génération 73 - global fitness : -2.3256465316516217
#
# génération 74 - global fitness : -1.9429272378125695
#
# génération 75 - global fitness : -2.442810412467811
#
# génération 76 - global fitness : -2.32335815858893
#
# génération 77 - global fitness : -2.4046448563154352
#
# génération 78 - global fitness : -2.7547196870454
#
# génération 79 - global fitness : -2.586625524495395
#
# génération 80 - global fitness : -2.7817959035321733
#
# génération 81 - global fitness : -2.890758007088571
#
# génération 82 - global fitness : -3.3565888397232144
#
# génération 83 - global fitness : -3.331954482962689
#
# génération 84 - global fitness : -2.637177403692989
#
# génération 85 - global fitness : -2.850815156385494
#
# génération 86 - global fitness : -2.661473584105656
#
# génération 87 - global fitness : -2.5428159664522942
#
# génération 88 - global fitness : -3.010417522388015
#
# génération 89 - global fitness : -2.3993704351556056
#
# génération 90 - global fitness : -2.8105696968671303
#
# génération 91 - global fitness : -2.566541184536815
#
# génération 92 - global fitness : -1.7296728342403214
#
# génération 93 - global fitness : -2.458494085989894
#
# génération 94 - global fitness : -2.4658795870742094
#
# génération 95 - global fitness : -2.8749731941860706
#
# génération 96 - global fitness : -3.685536809263789
#
# génération 97 - global fitness : -2.8930863379734206
#
# génération 98 - global fitness : -3.0095870001805354
#
# génération 99 - global fitness : -2.9475876500375624
#
# génération 100 - global fitness : -2.57828878112251
#
# génération 101 - global fitness : -2.4960267226005155
#
# génération 102 - global fitness : -2.627223929760084
#
# génération 103 - global fitness : -1.9209074251926455
#
# génération 104 - global fitness : -1.5106775497795153
#
# génération 105 - global fitness : -2.0057863382128733
#
# génération 106 - global fitness : -2.715897377369574
#
# génération 107 - global fitness : -2.7926993044914523
#
# génération 108 - global fitness : -2.9148027390800975
#
# génération 109 - global fitness : -2.3415062182061344
#
# génération 110 - global fitness : -1.7943355660483504
#
# génération 111 - global fitness : -1.7579795691005575
#
# génération 112 - global fitness : -1.7056338120676238
#
# génération 113 - global fitness : -2.225753122060591
#
# génération 114 - global fitness : -1.5471760783349386
#
# génération 115 - global fitness : -1.4932151924343335
#
# génération 116 - global fitness : -1.4602755927957776
#
# génération 117 - global fitness : -1.0564396426540543
#
# génération 118 - global fitness : -1.4818249760654478
#
# génération 119 - global fitness : -2.1215263236818203
#
# génération 120 - global fitness : -1.8655879112574025
#
# génération 121 - global fitness : -2.0435568506966213
#
# génération 122 - global fitness : -1.8053318050237845
#
# génération 123 - global fitness : -1.6862822696019715
#
# génération 124 - global fitness : -1.192264529011372
#
# génération 125 - global fitness : -1.7764708946731298
#
# génération 126 - global fitness : -1.9304014881475278
#
# génération 127 - global fitness : -1.6576772271711078
#
# génération 128 - global fitness : -1.7054151509439226
#
# génération 129 - global fitness : -1.4447685168907476
#
# génération 130 - global fitness : -1.761496612138186
#
# génération 131 - global fitness : -1.9227134421109353
#
# génération 132 - global fitness : -1.6986413219167218
#
# génération 133 - global fitness : -1.6538543217016402
#
# génération 134 - global fitness : -1.1396143024291037
#
# génération 135 - global fitness : -0.7973698068109261
#
# génération 136 - global fitness : -0.9888582229754377
#
# génération 137 - global fitness : -1.0296394070356438
#
# génération 138 - global fitness : -1.5319572725206023
#
# génération 139 - global fitness : -0.9828259674017538
#
# génération 140 - global fitness : -1.1954337533595851
#
# génération 141 - global fitness : -1.6088264609957974
#
# génération 142 - global fitness : -1.2036980619149558
#
# génération 143 - global fitness : -1.8853590298914455
#
# génération 144 - global fitness : -1.5206406708597675
#
# génération 145 - global fitness : -1.8887971521234064
#
# génération 146 - global fitness : -1.3567307603226126
#
# génération 147 - global fitness : -1.6759191055395357
#
# génération 148 - global fitness : -2.202584908767421
#
# génération 149 - global fitness : -1.5168932514427604
#
# génération 150 - global fitness : -0.9046160100986073
#
# génération 151 - global fitness : -0.7328057516403318
#
# génération 152 - global fitness : -1.1178171135638175
#
# génération 153 - global fitness : -1.6223363972571363
#
# génération 154 - global fitness : -1.4730572210287418
#
# génération 155 - global fitness : -0.971239596158906
#
# génération 156 - global fitness : -1.9461788943770113
#
# génération 157 - global fitness : -1.3665682222209938
#
# génération 158 - global fitness : -1.5008348995947747
#
# génération 159 - global fitness : -1.573086827911155
#
# génération 160 - global fitness : -0.885890890271336
#
# génération 161 - global fitness : -1.6946360548551882
#
# génération 162 - global fitness : -1.4012649185697958
#
# génération 163 - global fitness : -1.275649934756993
#
# génération 164 - global fitness : -1.1798090885572554
#
# génération 165 - global fitness : -1.0596898549593048
#
# génération 166 - global fitness : -1.1769400480375933
#
# génération 167 - global fitness : -0.9280806492307943
#
# génération 168 - global fitness : -1.1729930782597706
#
# génération 169 - global fitness : -1.056375639032457
#
# génération 170 - global fitness : -1.1260941780760971
#
# génération 171 - global fitness : -1.3830280463103675
#
# génération 172 - global fitness : -1.1849037836062264
#
# génération 173 - global fitness : -0.8912200440537744
#
# génération 174 - global fitness : -1.4415408790354736
#
# génération 175 - global fitness : -1.2491472708391465
#
# génération 176 - global fitness : -1.279656608823446
#
# génération 177 - global fitness : -0.6380697048485784
#
# génération 178 - global fitness : -1.2877765906215337
#
# génération 179 - global fitness : -0.600766972571735
#
# génération 180 - global fitness : -0.7923473921700291
#
# génération 181 - global fitness : -1.0942238695693414
#
# génération 182 - global fitness : -1.15289773815812
#
# génération 183 - global fitness : -0.696665141990506
#
# génération 184 - global fitness : -1.0874974500777246
#
# génération 185 - global fitness : -0.8564944563529011
#
# génération 186 - global fitness : -1.0114816408635792
#
# génération 187 - global fitness : -0.8903842321170417
#
# génération 188 - global fitness : -0.6163807638215328
#
# génération 189 - global fitness : -1.067069948159822
#
# génération 190 - global fitness : -0.8495202401918004
#
# génération 191 - global fitness : -0.8948400378314816
#
# génération 192 - global fitness : -0.5456717096777668
#
# génération 193 - global fitness : -0.7186571109164024
#
# génération 194 - global fitness : -1.3592504173263555
#
# génération 195 - global fitness : -1.0320924650705228
#
# génération 196 - global fitness : -0.7066369246915074
#
# génération 197 - global fitness : -0.41902233990921545
# Empty grid: no stats...
# Empty grid: no dump...
# [2022-12-08 22:46:03,155] launcher  (127.0.0.1:46047) INFO    Root process is done.
# [2022-12-08 22:46:03,156] launcher  (127.0.0.1:46047) INFO    Finished cleaning spawned subprocesses.

# %%
# fit dossier : question_3_fit

import pandas as pd

path_fit = "./question_3_fit/bd.log"
path_ns = "./question_3_ns/bd.log"
path_fit_ns = "./question_3_fit_ns/bd.log"

df_ns = pd.read_csv(path_ns, names=["x","y"] , delimiter=" ")
df_fit = pd.read_csv(path_fit, names=["x","y"] , delimiter=" ")
df_fit_ns = pd.read_csv(path_fit_ns, names=["x","y"] , delimiter=" ")

# display(df)

# print(df["x"])

plt.figure(figsize=(10,7))
plt.title("Position finale des derniers point générés")
plt.scatter(df_ns["x"],df_ns["y"] ,label="NS")
plt.scatter(df_fit_ns["x"],df_fit_ns["y"], label="FIT+NS")
plt.scatter(df_fit["x"],df_fit["y"], label="FIT")

plt.legend()
#plt.scatter(df_fit["x"],df_fit["y"])
plt.show()


# <à compléter>

# décrivez en quelques mots ce que vous avez fait et tracez les figures demandées.

# %% [markdown]
# **Commentaire**: Nous avons executé les versions FIT,FIT+NS et NS, nous avons récupéré les données dans le fichier bd.log avec l'aide de pandas. Enfin, nous avons tracé à laide de matplotlib les points.
#
# **Remarque**: Nous voyons que l'approche NS explore le plus car elle couvre une plus grande zone de points, ensuite FIT+NS et enfin NS.

# %% [markdown]
# Tracez sur des figures séparées les points générés pour plusieurs générations successives de NS, FIT et FIT+NS (par exemple 90, 91, 92). Que constatez vous ?

# %% [markdown]
# ## Observation FIT

# %%
path_fit_fit = "./question_3_fit/fit.log"
with open(path_fit_fit, "r") as file:
    f = file.read()
    l = f.split("\n")
    list_index = list()
    for i in range(len(l)) :
        if "Generation" in l[i] :
            list_index.append(i)
            
path_fit_bd = "./question_3_fit/bd.log"
df_fit = pd.read_csv(path_fit_bd, names=["x","y"] , delimiter=" ")
print("Nombre de générations : "+str(len(list_index)))
generations = [0,1,2,3]

# Affichage

fig, axs = plt.subplots(1, 3, figsize=(18, 6))

axs[0].scatter(df_fit["x"][list_index[generations[0]] : list_index[generations[1]]],
            df_fit["y"][list_index[generations[0]] : list_index[generations[1]]])

axs[1].scatter(df_fit["x"][list_index[generations[1]] : list_index[generations[2]]],
            df_fit["y"][list_index[generations[1]] : list_index[generations[2]]])

axs[2].scatter(df_fit["x"][list_index[generations[2]] : list_index[generations[3]]],
            df_fit["y"][list_index[generations[2]] : list_index[generations[3]]])
# Out:
# Nombre de générations : 24

# %% [markdown]
# **Commentaire**:

# %% [markdown]
# ## Observation NS

# %%
path_ns_fit = "./question_3_ns/fit.log"
with open(path_ns_fit, "r") as file:
    f = file.read()
    l = f.split("\n")
    list_index = list()
    for i in range(len(l)) :
        if "Generation" in l[i] :
            list_index.append(i)
            
print("Nombre de générations : "+str(len(list_index)))
path_ns_bd = "./question_3_ns/bd.log"
df_ns = pd.read_csv(path_ns_bd, names=["x","y"] , delimiter=" ")

generations = [0,1,2,3]

# Affichage

fig, axs = plt.subplots(1, 3, figsize=(18, 6))

axs[0].set_title("Generation "+str(generations[0])+" : points générés pour NS")
axs[0].scatter(df_ns["x"][list_index[generations[0]] : list_index[generations[1]]],
            df_ns["y"][list_index[generations[0]] : list_index[generations[1]]])

axs[1].set_title("Generation "+str(generations[1])+" : points générés pour NS")
axs[1].scatter(df_ns["x"][list_index[generations[1]] : list_index[generations[2]]],
            df_ns["y"][list_index[generations[1]] : list_index[generations[2]]])

axs[2].set_title("Generation "+str(generations[2])+" : points générés pour NS")
axs[2].scatter(df_ns["x"][list_index[generations[2]] : list_index[generations[3]]],
            df_ns["y"][list_index[generations[2]] : list_index[generations[3]]])
# Out:
# Nombre de générations : 421

# %% [markdown]
# **Commentaire**:

# %% [markdown]
# ## Observation FIT+NS

# %%
path_fn_fit = "./question_3_fit_ns/fit.log"
with open(path_fn_fit, "r") as file:
    f = file.read()
    l = f.split("\n")
    list_index = list()
    for i in range(len(l)) :
        if "Generation" in l[i] :
            list_index.append(i)
            
print("Nombre de générations : "+str(len(list_index)))
path_fn_bd = "./question_3_fit_ns/bd.log"
df_fn = pd.read_csv(path_fn_bd, names=["x","y"] , delimiter=" ")

generations = [0,1,2,3]

# Affichage

fig, axs = plt.subplots(1, 3, figsize=(18, 6))

axs[0].scatter(df_fn["x"][list_index[generations[0]] : list_index[generations[1]]],
            df_fn["y"][list_index[generations[0]] : list_index[generations[1]]])

axs[1].scatter(df_fn["x"][list_index[generations[1]] : list_index[generations[2]]],
            df_fn["y"][list_index[generations[1]] : list_index[generations[2]]])

axs[2].scatter(df_fn["x"][list_index[generations[2]] : list_index[generations[3]]],
            df_fn["y"][list_index[generations[2]] : list_index[generations[3]]])
# Out:
# Nombre de générations : 198

# %% [markdown]
# **Commentaire**:

# %%
# <à compléter>

# décrivez en quelques mots ce que vous avez fait et tracez les figures demandées.

# %% [markdown]
# ## 4 Ajout d'une qualité locale
#
# L'ensemble des solutions générées peut être utilisé pour atteindre n'importe lequel des comportements atteignables, mais l'inconvénient de cette approche est que la notion de qualité est totalement absente du processus, or parmi les solutions générant un comportement donné, toutes ne se valent pas. Certaines sont plus intéressantes que d'autres parce qu'elle consomment moins d'énergie, qu'elles ne créent pas de collision, qu'elles sont plus stables, etc.
#
# Une solution pour prendre en compte un tel critère de qualité consiste à utiliser, à côté de l'objectif de nouveauté, un objectif de performance. Définir cet objectif comme une pression globale est contreproductif, car pour éviter des collisions ou minimiser la consommation d'énergie, il suffit de ne pas bouger... Pour rendre cette pression plus intéressante, il faut en faire un objectif non pas global, mais local.
#
# Pour cela, on peut suivre l'approche proposée par Lehman et Stanley [1]: on compare la fitness de l'individu considéré avec celle de ses plus proches voisins (qui sont déjà déterminés pour le calcul de nouveauté). On ajoute alors un objectif de compétition locale qui vaut le nombre de voisins dont la fitness est inférieure.
#
# Complétez le code de novelty_search.py pour que la fonction de calcul de nouveauté renvoie la nouveauté et l'objectif de compétition locale. Pour cela, vous devrez garder dans l'archive la liste des fitness des points ajoutés.
#
# Utilisez cette nouvelle version pour générer des politiques qui permettent d'atteindre les différentes positions de l'espace en minimisant un tel critère, par exemple l'écart-type sur les angles du bras.
#
# Vous créerez une nouvelle variante et reprendrez le tracé de l'espace exploré en indiquant par une couleur la qualité de chaque point ("heat-map"). Vous comparerez, visuellement, les résultats des différentes variantes.
#
# * [1] Lehman, J., & Stanley, K. O. (2011). Evolving a diversity of virtual creatures through novelty search and local competition. In Proceedings of GECCO

# %%
# !python3 -m scoop ea_dps_ka2.py
# Out:
# [2022-12-09 10:04:28,331] launcher  INFO    SCOOP 0.7 1.1 on linux using Python 3.8.10 (default, Jun 22 2022, 20:18:18) [GCC 9.4.0], API: 1013
# [2022-12-09 10:04:28,331] launcher  INFO    Deploying 4 worker(s) over 1 host(s).
# [2022-12-09 10:04:28,331] launcher  INFO    Worker distribution:
# [2022-12-09 10:04:28,331] launcher  INFO       127.0.0.1:	3 + origin
# /home/jdufou1/.local/lib/python3.8/site-packages/deap/creator.py:138: RuntimeWarning: A class named 'MyFitness' has already been created and it will be overwritten. Consider deleting previous creation of that class or rename it.
#   warnings.warn("A class named '{0}' has already been created and it "
# /home/jdufou1/.local/lib/python3.8/site-packages/deap/creator.py:138: RuntimeWarning: A class named 'Individual' has already been created and it will be overwritten. Consider deleting previous creation of that class or rename it.
#   warnings.warn("A class named '{0}' has already been created and it "
# /home/jdufou1/.local/lib/python3.8/site-packages/deap/creator.py:138: RuntimeWarning: A class named 'Strategy' has already been created and it will be overwritten. Consider deleting previous creation of that class or rename it.
#   warnings.warn("A class named '{0}' has already been created and it "
# passage get_nov
# bd :  [-0.98876031  0.05797699]
# population :  [Individual('d', [-0.30183708748132765, -0.4169947765430862, -0.5328317385974684, -0.5364808363985393, -0.5111857263204302, -0.7249676362312628, -0.4086169367551138, -0.6592023705707694, 0.7596382484092206, 0.5031067413422459]), Individual('d', [-0.8707961425554358, 0.46284724187514326, 0.522839393582698, -0.07344768966040105, 0.7558323243237013, -0.7759051128154535, 0.8828326578144421, -0.4099284128264642, 0.841650667120222, -0.23589141801183033]), Individual('d', [-0.8707961425554358, 0.46284724187514326, 0.522839393582698, -0.07344768966040105, 0.7558323243237013, -0.7759051128154535, 0.8828326578144421, -0.4099284128264642, 0.841650667120222, -0.23589141801183033]), Individual('d', [-0.23576317508930572, -0.5708175409486509, -0.8982065403487037, -0.027216520996620863, 0.8096420005369407, -0.1726635699020704, -0.8653484819347139, -0.25962356597434155, -0.6839415434086494, -0.2863057990794527]), Individual('d', [-0.6871721487877029, 0.34398797110842927, -0.7160953452928025, 0.6479040622702643, -0.7952187488717957, -0.6755793740001113, -0.491484553324947, 0.8268704031409451, 0.18048093312274682, -0.04000875120189251]), Individual('d', [0.3282129074020871, -0.4396032925452169, 0.09477368920227286, -0.5449917824221648, -0.8482845549445784, 0.40927409609011656, -0.010181857742601337, 0.10591754047495228, -0.7829962560630849, 0.6582334971787303]), Individual('d', [0.3662938000910472, -0.4374924512154597, -0.5235817703946093, 0.13923500906066844, -0.5691648995494614, -0.7996117232305286, 0.24477869949437348, 0.6280846546095102, -0.21812624330482722, -0.05415107422075027]), Individual('d', [-0.2357074251224549, 0.5211022940157881, 0.6228644744366647, -0.8863604563231506, -0.9826622233526678, 0.3560029110955252, -0.15023506335269476, -0.9298392576900958, 0.9090309194453745, -0.09815549458157347]), Individual('d', [-0.5250427362136842, 0.4961357719004089, 0.7699416379805473, -0.6909949449285806, -0.12491287717214883, 0.4523287319085336, 0.5458115020906571, 0.24832916023914597, -0.407325862384172, 0.6232192159368659]), Individual('d', [-0.5250427362136842, 0.4961357719004089, 0.7699416379805473, -0.6909949449285806, -0.12491287717214883, 0.4523287319085336, 0.5458115020906571, 0.24832916023914597, -0.407325862384172, 0.6232192159368659]), Individual('d', [-0.5250427362136842, 0.4961357719004089, 0.7699416379805473, -0.6909949449285806, -0.12491287717214883, 0.4523287319085336, 0.5458115020906571, 0.24832916023914597, -0.407325862384172, 0.6232192159368659]), Individual('d', [-0.1968719782256827, 0.9162030017607528, -0.05909835923737172, -0.41112119143198145, 0.6106319535337019, 0.07346777877961186, 0.5588894810108925, -0.5534764854937335, -0.8421432679433005, -0.3358410014287141]), Individual('d', [0.14681905897020275, -0.15658595209968973, 0.8013449827626726, -0.7982966852765963, -0.7360913212284476, -0.1931908381127292, -0.7746850884271221, 0.7186072840078332, -0.26992231177846016, 0.839049222502295]), Individual('d', [-0.22815453279103015, -0.5185196177314504, -0.9075475017284345, 0.6672023296001908, 0.37564657882690344, 0.02142357661716865, -0.8651165940752203, 0.6739647122328665, -0.8287109106528734, -0.3834026529681054]), Individual('d', [-0.22815453279103015, -0.5185196177314504, -0.9075475017284345, 0.6672023296001908, 0.37564657882690344, 0.02142357661716865, -0.8651165940752203, 0.6739647122328665, -0.8287109106528734, -0.3834026529681054]), Individual('d', [-0.22815453279103015, -0.5185196177314504, -0.9075475017284345, 0.6672023296001908, 0.37564657882690344, 0.02142357661716865, -0.8651165940752203, 0.6739647122328665, -0.8287109106528734, -0.3834026529681054]), Individual('d', [-0.3840880971998091, -0.7298819805522654, 0.6574316854679547, -0.6790299229339998, 0.8152502661256453, 0.4104535075933118, 0.5092849608300456, -0.4541145332945631, -0.8052413283850417, -0.6493014844762632]), Individual('d', [-0.3840880971998091, -0.7298819805522654, 0.6574316854679547, -0.6790299229339998, 0.8152502661256453, 0.41045 ...

# %%
# <à compléter>

# indiquez rapidement ce que vous avez fait, puis donnez les tracés des espaces explorés colorés 
# par la qualité locale. Vous donnerez un commentaire rapide de ces résultats.

# %% [markdown]
# ## 5 "Illuminer" l'espace exploré
#
# ### 5.1 Quantifier l'espace comportemental exploré

# %% [markdown]
# Définissez une grille dans l'espace comportemental qui va vous permettre de mesurer l'espace exploré. Découpez l'espace en cases (vous ignorerez les murs pour simplifier) et écrivez une fonction permettant de placer un individu dans la case correspondant à son descripteur comportemental une fois qu'il a été évalué. Il n'y aura qu'un seul individu par case. Lorsque vous tentez d'ajouter un individu dans une case, si elle est déjà remplie, le nouvel individu remplacera l'ancien si sa fitness est plus élevée.
#
# Cette grille est (pour l'instant) indépendante de l'algorithme d'apprentissage. Elle vise simplement à mesurer la capacité de ce dernier à explorer cet espace et à retrouver facilement, si besoin, une politique efficace permettant d'atteindre un comportement donné.
#
# Vous mesurerez la couverture de votre exploration (pourcentage de cellules explorées). Utilisez une grille de 100x100 cases et déterminez la couverture pour les trois variantes: FIT, NS, FIT+NS et NSLC (vous pourrez vous contenter d'une seule expérience).

# %%
# <à compléter>

# indiquez rapidement ce que vous avez fait et les résultats trouvés.

# %% [markdown]
# ### 5.2 MAP-Elites
#
# #### 5.2.1 Implémentation de MAP-Elites
#
# La grille définie à la question précédente permet de définir un algorithme très simple: MAP-Elites [1]. Dans cet algorithme, la sélection s'appuie sur la grille. La génération d'un nouvel individu consiste à tirer aléatoirement un (si mutation uniquement) ou deux individus (si croisement) dans la grille puis à appliquer l'opérateur génétique de mutation ou de croisement. Après évaluation, on tente d'ajouter cet individu dans la grille. Si la case correspondante est vide, on l'ajoute, sinon, on le compare à l'individu déjà présent et on le remplace si la fitness est améliorée.
#
# Utilisez cet algorithme sur la tâche précédente et affichez les résultats: évolution de la couverture et grille finale obtenue.
#
#
#
# * [1] Mouret, J. B., & Clune, J. (2015). Illuminating search spaces by mapping elites. arXiv preprint arXiv:1504.04909

# %%
# <à compléter>

# indiquez ici les résultats trouvés

# %% [markdown]
# #### 5.2.2 OPTION: Variantes de MAP-Elites
#
# MAP-Elites peut aussi être amélioré avec des stratégies de choix des parents qui ne sont plus uniformes sur toute la grille, mais biaisées pour favoriser les cellules isolées ou les individus dont les descendants ont réussi à remplir des cellules (score de "curiosité" [1]). Testez cette variante sur la tâche précédente et observez l'évolution de la couverture ainsi que la grille finale obtenue.
#
# * [1] Cully, A., & Demiris, Y. (2017). Quality and diversity optimization: A unifying modular framework. IEEE Transactions on Evolutionary Computation, 22(2), 245-259.

# %%
# <à compléter>

# indiquez ici les résultats trouvés
